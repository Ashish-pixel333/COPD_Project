# %%
# import the libraries needed
import pandas as pd
import numpy as np

# %%
# Load the dataset
path = r"C:\Users\LENOVO\Desktop\Project\Data\Project_data.csv"
df = pd.read_csv(path)
df.head()
# Out:
#    Age  Gender Smoking_Status  Biomass_Fuel_Exposure  Occupational_Exposure  \
# 0   37  Female         Former                   True                  False
# 1   46    Male         Former                  False                   True
# 2   72    Male        Current                   True                  False
# 3   38  Female          Never                   True                  False
# 4   75    Male        Current                  False                  False
#
#    Family_History_COPD    BMI  Location  Air_Pollution_Level  \
# 0                False  33.42  Lalitpur                  235
# 1                 True  24.73  Lalitpur                   68
# 2                False  23.40   Birgunj                   98
# 3                 True  30.26  Lalitpur                  255
# 4                 True  30.20  Lalitpur                  176
#
#    Respiratory_Infections_Childhood  COPD_Diagnosis
# 0                             False           False
# 1                             False            True
# 2                              True            True
# 3                             False            True
# 4                              True           False

# %%
# Age categories
df['Age_Category'] = pd.cut(df['Age'], bins=[29, 39, 49, 59, 69, 79], labels = ['30 - 39', '40 - 49', '50 - 59', '60 - 69', '70 - 79'])

df['BMI_Categories'] = pd.cut(df['BMI'], bins = [0, 18.5, 24.5, 29.9, 35], labels= ['Underweight', 'Normal Weight', 'Overweight', 'Obessity'])

# %%
# Pollution Risk Score
df['Pollution_Risk_Score'] = np.where(df['Air_Pollution_Level'] > 150, 1, 0)

# Encode smoking status
df["Smoking_Status_encoded"] = df["Smoking_Status"].map({"Current":1, "Former":0.5, "Never": 0})

# encode gender
df["Gender"] = df["Gender"].map({"Male":1, "Female": 0})


# Interaction Features - Smoking status and pollution level
df['Smoking_Pollution_interaction'] = df['Smoking_Status_encoded'] * df['Air_Pollution_Level']

# %%
#One hot encoding for location
df = pd.get_dummies(df, columns=['Location'], drop_first=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Age                               1000 non-null   int64
#  1   Gender                            1000 non-null   int64
#  2   Smoking_Status                    1000 non-null   object
#  3   Biomass_Fuel_Exposure             1000 non-null   bool
#  4   Occupational_Exposure             1000 non-null   bool
#  5   Family_History_COPD               1000 non-null   bool
#  6   BMI                               1000 non-null   float64
#  7   Air_Pollution_Level               1000 non-null   int64
#  8   Respiratory_Infections_Childhood  1000 non-null   bool
#  9   COPD_Diagnosis                    1000 non-null   bool
#  10  Age_Category                      1000 non-null   category
#  11  BMI_Categories                    1000 non-null   category
#  12  Pollution_Risk_Score              1000 non-null   int64
#  13  Smoking_Status_encoded            1000 non-null   float64
#  14  Smoking_Pollution_interaction     1000 non-null   float64
#  15  Location_Biratnagar               1000 non-null   bool
#  16  Location_Birgunj                  1000 non-null   bool
#  17  Location_Dharan                   1000 non-null   bool
#  18  Location_Kathmandu                1000 non-null   bool
#  19  Location_Lalitpur                 1000 non-null   bool
#  20  Location_Pokhara                  1000 non-null   bool
#  21  Location_Rupandehi                1000 non-null   bool
# dtypes: bool(12), category(2), float64(3), int64(4), object(1)
# memory usage: 76.7+ KB

# %% [markdown]
# ## Machine Learning Data

# %%
df = df.drop(columns=["Smoking_Status", "Age_Category", "BMI_Categories"])

# %%
df.to_csv("../data/engineered_copd_data.csv", index=False)

# %%
df.head()
# Out:
#    Age  Gender  Biomass_Fuel_Exposure  Occupational_Exposure  \
# 0   37       0                   True                  False
# 1   46       1                  False                   True
# 2   72       1                   True                  False
# 3   38       0                   True                  False
# 4   75       1                  False                  False
#
#    Family_History_COPD    BMI  Air_Pollution_Level  \
# 0                False  33.42                  235
# 1                 True  24.73                   68
# 2                False  23.40                   98
# 3                 True  30.26                  255
# 4                 True  30.20                  176
#
#    Respiratory_Infections_Childhood  COPD_Diagnosis  Pollution_Risk_Score  \
# 0                             False           False                     1
# 1                             False            True                     0
# 2                              True            True                     0
# 3                             False            True                     1
# 4                              True           False                     1
#
#    Smoking_Status_encoded  Smoking_Pollution_interaction  Location_Biratnagar  \
# 0                     0.5                          117.5                False
# 1                     0.5                           34.0                False
# 2                     1.0                           98.0                False
# 3                     0.0                            0.0                False
# 4                     1.0                          176.0                False
#
#    Location_Birgunj  Location_Dharan  Location_Kathmandu  Location_Lalitpur  \
# 0             False            False               False               True
# 1             False            False               False               True
# 2              True            False               False              False
# 3             False            False               False               True
# 4             False            False               False               True
#
#    Location_Pokhara  Location_Rupandehi
# 0             False               False
# 1             False               False
# 2             False               False
# 3             False               False
# 4             False               False
