# %% [markdown]
# # COPD in Nepal
# ### Factors that lead to COPD
# 1. Biomass Fuel Exposure (Indoor AIr pollution)
# 2. Tobacco Smoking
# 3. Outdoor Air pollution
# 4. Occupational Exposure(exposure from work relating to veichles and pollutanats)
# 5. Genetic susceptability(Family genetics susceptibility)
# 6. Respiratory Infections
# 7. Low Awareness and health Access
# 8. Climate and Environmental factors

# %% [markdown]
# # Signs and symptoms of COPD
# 1. Chronic Cough
# 2. Shortness of Breath (Dyspnea)
# 3. Excess mucus production (Sputum) (Phlegm)
# 4. Wheezing
# 5. Fatigue and low energy
# 6. Chest tightness
# 7. Frequent Respiratory Infections
# 8. Cynosis (Bluish lips or Fingernail beds)
# 9. Unintended Weight
# 10. Chronic Bronchitis and Emphysema Symptoms
# 11. Frequent Flare-ups (Exacerbations)

# %%
# Import the libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
path = r"C:\Users\LENOVO\Desktop\Project\Data\Project_data.csv"
df = pd.read_csv(path)
df.head()
# Out:
#    Age  Gender Smoking_Status  Biomass_Fuel_Exposure  Occupational_Exposure  \
# 0   37  Female         Former                   True                  False
# 1   46    Male         Former                  False                   True
# 2   72    Male        Current                   True                  False
# 3   38  Female          Never                   True                  False
# 4   75    Male        Current                  False                  False
#
#    Family_History_COPD    BMI  Location  Air_Pollution_Level  \
# 0                False  33.42  Lalitpur                  235
# 1                 True  24.73  Lalitpur                   68
# 2                False  23.40   Birgunj                   98
# 3                 True  30.26  Lalitpur                  255
# 4                 True  30.20  Lalitpur                  176
#
#    Respiratory_Infections_Childhood  COPD_Diagnosis
# 0                             False           False
# 1                             False            True
# 2                              True            True
# 3                             False            True
# 4                              True            True

# %%
# Setting up large plot for data
plt.figure(figsize=(14, 8))

# %%
# Info about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Age                               1000 non-null   int64
#  1   Gender                            1000 non-null   object
#  2   Smoking_Status                    1000 non-null   object
#  3   Biomass_Fuel_Exposure             1000 non-null   bool
#  4   Occupational_Exposure             1000 non-null   bool
#  5   Family_History_COPD               1000 non-null   bool
#  6   BMI                               1000 non-null   float64
#  7   Location                          1000 non-null   object
#  8   Air_Pollution_Level               1000 non-null   int64
#  9   Respiratory_Infections_Childhood  1000 non-null   bool
#  10  COPD_Diagnosis                    1000 non-null   bool
# dtypes: bool(5), float64(1), int64(2), object(3)
# memory usage: 51.9+ KB

# %% [markdown]
# ### Univariate Analysis

# %%
sns.histplot(df['Age'], kde = True, color='blue')
plt.title("Age Distribution")
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
# BMI Distribution
sns.histplot(df['BMI'], kde = True, color='green')
plt.title("BMI Distribution")
# Out:
# Text(0.5, 1.0, 'BMI Distribution')

# %%
# gender distribution
sns.countplot(x = 'Gender', data = df, palette='viridis')
plt.title("Gender Distribution")
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_4232\1850183835.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'Gender', data = df, palette='viridis')
# Text(0.5, 1.0, 'Gender Distribution')

# %%
# Smoking Status
sns.countplot(x = "Smoking_Status", data = df, palette='Set1')
plt.title("Smoking status Distribution")
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_4232\4228344977.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = "Smoking_Status", data = df, palette='Set1')
# Text(0.5, 1.0, 'Smoking status Distribution')

# %%
sns.countplot(x = "Biomass_Fuel_Exposure", data = df, palette='Set1')
plt.title("Biomass_Fuel_Exposure Distribution")
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_4232\3103921392.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = "Biomass_Fuel_Exposure", data = df, palette='Set1')
# Text(0.5, 1.0, 'Biomass_Fuel_Exposure Distribution')

# %% [markdown]
# Bivarate Analysis

# %%
# Age vs COPD Diagnosis
sns.boxplot(x = 'COPD_Diagnosis', y = 'Age', data = df, palette='coolwarm')
plt.title("Age vs COPD Diagnosis")
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_4232\200594672.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'COPD_Diagnosis', y = 'Age', data = df, palette='coolwarm')

# %%
#BMI vs COPD diagnosis
sns.boxplot(x = 'COPD_Diagnosis', y = 'BMI', data = df, palette="coolwarm")
plt.title("BMI vs COPD_Diagnosis")
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_4232\108076601.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'COPD_Diagnosis', y = 'BMI', data = df, palette="coolwarm")

# %%
#Smoking Status
sns.boxplot(x = 'Smoking_Status', hue='COPD_Diagnosis', data = df, palette='Set2')
plt.title("Smoking Status vs COPD_Diagnosis")
plt.show()

# %%
#Smoking Status
sns.boxplot(x = 'Biomass_Fuel_Exposure', hue='COPD_Diagnosis', data = df, palette='Set2')
plt.title("Biomass_Fuel_Exposure vs COPD_Diagnosis")
plt.show()

# %%
sns.countplot(x = 'COPD_Diagnosis', data = df, palette='viridis')
plt.title("Count plot of COPD Diagnosis")
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_4232\4144989369.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'COPD_Diagnosis', data = df, palette='viridis')

# %%
# pair plot
sns.pairplot(df, hue='COPD_Diagnosis', diag_kind='kde', palette='Set1')
plt.title("Pair Plot")
plt.show()

# %%
# COrrelation Matrix
data_corr = df[['Age', 'Biomass_Fuel_Exposure', 'Occupational_Exposure', 'Family_History_COPD', 'BMI', 'Air_Pollution_Level', 'Respiratory_Infections_Childhood', 'COPD_Diagnosis']]
corr = data_corr.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Matrix")
plt.show()
